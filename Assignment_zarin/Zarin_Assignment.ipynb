# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("E:\DataAnal_Andrew\zdata.csv")

# %%
Sr = data['Sr (in ppm)']
Y = data['Y (in ppm)']
SiO2=data['SiO2']
Sr_Y=data['Sr/Y']
CaO=data['CaO']
K2O=data['K2O']
Rb=data['Rb']

# %%
data
# Out:
#   SampleID   SiO2  Sr (in ppm)  Y (in ppm)    Sr/Y   CaO   K2O  Rb
# 0   424.1P  54.37          634          18   35.22  7.70  1.08  38
# 1   425.1P  64.98          492          11   44.73  4.85  1.77  51
# 2   400.1W  69.04          488           5   97.60  4.18  1.62  40
# 3   403.1W  72.69          435           8   54.38  2.64  1.70  38
# 4   402.1D  72.24          653           1  653.00  4.15  0.62  20
# 5   402.2D  58.17          423          23   18.39  7.31  0.90  28

# %%
ss = 50

s1 = plt.scatter(SiO2,Sr_Y,c='r',s=ss)
# plt.xlim(50.00,80.00)
# plt.ylim(0,700)
plt.xlabel('SiO2 (in %)')
plt.ylabel('Sr/Y')
# Out:
# Text(0, 0.5, 'Sr/Y')

# %%
s2 = plt.scatter(SiO2,Sr,s=ss)
#plt.xlim(50,80)
#plt.ylim(400,700)
plt.xlabel('SiO2 (in %)')
plt.ylabel('Sr(in ppm)')
# Out:
# Text(0, 0.5, 'Sr(in ppm)')

# %%
s3 = plt.scatter(SiO2,CaO,s=ss)
# plt.xlim(50,80)
# plt.ylim(0,9)
plt.xlabel('SiO2 (in %)')
plt.ylabel('CaO')
# Out:
# Text(0, 0.5, 'CaO')

# %%
s4 = plt.scatter(SiO2,K2O,s=ss)
# plt.xlim(50,80)
# plt.ylim(0,2)
plt.xlabel('SiO2 (in %)')
plt.ylabel('K2O')
# Out:
# Text(0, 0.5, 'K2O')

# %%
s5 = plt.scatter(SiO2,Rb,s=ss)
# plt.xlim(50,80)
# plt.ylim(0,50)
plt.xlabel('SiO2 (in %)')
plt.ylabel('Rb')
# Out:
# Text(0, 0.5, 'Rb')
